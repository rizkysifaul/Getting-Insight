# %% [markdown]
# This tutorial is based on *Practical Guide to Exploratory Data Analysis* at **Make-AI Indonesia** For more information about this check out http://make-ai.id/ .
#
# Have fun !!!

# %% [markdown]
# First thing first is import the importances package for doing data science work.

# %%
#core package for data science
import numpy as np
import pandas as pd

#import package for data visualization
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#hide warnings so you can't find any warning
import warnings 
warnings.simplefilter('ignore')

from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode("offline")

print("Done !!!")
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# Done !!!

# %% [markdown]
# For now, we are using famous dataset, about Life Expectancy in the World.
#
# One of dataset we are using is from here : https://www.kaggle.com/kumarajarshi/life-expectancy-who

# %% [markdown]
# Import the data

# %%
data = pd.read_csv("Life Expectancy Data.csv")
data.sample(5).T
# Out:
#                                          2302        294          2554  \
# Country                          Sierra Leone      Bhutan   Tajikistan
# Year                                     2010        2009         2014
# Status                             Developing  Developing   Developing
# Life expectancy                          48.1        67.4         69.6
# Adult Mortality                           424         232          162
# infant deaths                              27           1           10
# Alcohol                                  3.84        0.17         0.01
# percentage expenditure                5.34772     27.4891      7.82901
# Hepatitis B                                86          93           97
# Measles                                  1089           6            0
#  BMI                                     21.7        19.5         39.9
# under-five deaths                          40           1           11
# ...

# %% [markdown]
# How we know what is it data about? This is about information about each column.

# %% [markdown]
# **Country** :
# Country
#
# **Year** :
# Year
#
# **Status** :
# Developed or Developing status
#
# **Life expectancy** :
# Life Expectancy in age
#
# **Adult Mortality** :
# Adult Mortality Rates of both sexes (probability of dying between 15 and 60 years per 1000 population)
#
# **infant deaths** :
# Number of Infant Deaths per 1000 population
#
# **Alcohol** :
# Alcohol, recorded per capita (15+) consumption (in litres of pure alcohol)
#
# **percentage expenditure** :
# Expenditure on health as a percentage of Gross Domestic Product per capita(%)
#
# **Hepatitis B** :
# Hepatitis B (HepB) immunization coverage among 1-year-olds (%)
#
# **Measles** :
# Measles - number of reported cases per 1000 population
#
# **BMI** :
# Average Body Mass Index of entire population
#
# **under-five deaths** :
# Number of under-five deaths per 1000 population
#
# **Polio** :
# Polio (Pol3) immunization coverage among 1-year-olds (%)
#
# **Total expenditure** :
# General government expenditure on health as a percentage of total government expenditure (%)
#
# **Diphtheria** :
# Diphtheria tetanus toxoid and pertussis (DTP3) immunization coverage among 1-year-olds (%)
#
# **HIV/AIDS** :
# Deaths per 1 000 live births HIV/AIDS (0-4 years)
#
# **GDP** :
# Gross Domestic Product per capita (in USD)
#
# **Population** :
# Population of the country
#
# **thinness 1-19 years** :
# Prevalence of thinness among children and adolescents for Age 10 to 19 (% )
#
# **thinness 5-9 years** :
# Prevalence of thinness among children for Age 5 to 9(%)
#
# **Income composition of resources** :
# Human Development Index in terms of income composition of resources (index ranging from 0 to 1)
#
# **Schooling** :
# Number of years of Schooling(years)

# %% [markdown]
# Get information of your data.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
# Country                            2938 non-null object
# Year                               2938 non-null int64
# Status                             2938 non-null object
# Life expectancy                    2928 non-null float64
# Adult Mortality                    2928 non-null float64
# infant deaths                      2938 non-null int64
# Alcohol                            2744 non-null float64
# percentage expenditure             2938 non-null float64
# Hepatitis B                        2385 non-null float64
# Measles                            2938 non-null int64
#  BMI                               2904 non-null float64
# under-five deaths                  2938 non-null int64
# Polio                              2919 non-null float64
# Total expenditure                  2712 non-null float64
# Diphtheria                         2919 non-null float64
# ...

# %% [markdown]
# Get statistical value for our data.

# %%
data.describe().T
# Out:
#                                   count          mean           std  \
# Year                             2938.0  2.007519e+03  4.613841e+00
# Life expectancy                  2928.0  6.922493e+01  9.523867e+00
# Adult Mortality                  2928.0  1.647964e+02  1.242921e+02
# infant deaths                    2938.0  3.030395e+01  1.179265e+02
# Alcohol                          2744.0  4.602861e+00  4.052413e+00
# percentage expenditure           2938.0  7.382513e+02  1.987915e+03
# Hepatitis B                      2385.0  8.094046e+01  2.507002e+01
# Measles                          2938.0  2.419592e+03  1.146727e+04
#  BMI                             2904.0  3.832125e+01  2.004403e+01
# under-five deaths                2938.0  4.203574e+01  1.604455e+02
# Polio                            2919.0  8.255019e+01  2.342805e+01
# Total expenditure                2712.0  5.938190e+00  2.498320e+00
# Diphtheria                       2919.0  8.232408e+01  2.371691e+01
# ...

# %% [markdown]
# Get column name of your data.

# %%
data.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %% [markdown]
# Get visualize your data !

# %% [markdown]
# ### Box Plot

# %%
sns.boxplot(y="Life expectancy ", data=data);

# %% [markdown]
# ### Distribution Plot

# %%
sns.distplot(data["under-five deaths "],kde=False);

# %% [markdown]
# ### Violin Plot

# %%
sns.violinplot(x=data[" HIV/AIDS"]);

# %% [markdown]
# ### Heatmap for Correlation Plot

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data.corr(),annot=True);

# %% [markdown]
# ### Slicing Data ASEAN Countries

# %%
asean = data[(data["Country"] == "Indonesia") | (data["Country"] == "Malaysia") | (data["Country"] == "Singapore")
            |(data["Country"] == "Thailand") |(data["Country"] == "Philipines")|(data["Country"] == "Brunei Darussalam")|
             (data["Country"] == "Laos")|(data["Country"] == "Cambodia")|(data["Country"] == "Timor Leste")|
             (data["Country"] == "Myanmar")|(data["Country"] == "Vietnam")]

# %%
asean.head()
# Out:
#                Country  Year      Status  Life expectancy   Adult Mortality  \
# 368  Brunei Darussalam  2015  Developing              77.7             78.0
# 369  Brunei Darussalam  2014  Developing              77.6              8.0
# 370  Brunei Darussalam  2013  Developing              77.1             84.0
# 371  Brunei Darussalam  2012  Developing              78.3             79.0
# 372  Brunei Darussalam  2011  Developing              77.4             79.0
#
#      infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 368              0      NaN                0.000000         99.0         4
# 369              0     0.01              269.143278         99.0         1
# 370              0     0.01             2845.306444         98.0         0
# 371              0     0.01             3192.634413         99.0         1
# 372              0     0.97              295.773017         93.0         4
#
# ...

# %% [markdown]
# How many country from ASEAN are in our data?

# %%
asean["Country"].unique()
# Out:
# array(['Brunei Darussalam', 'Cambodia', 'Indonesia', 'Malaysia',
#        'Myanmar', 'Singapore', 'Thailand'], dtype=object)

# %% [markdown]
# Unfortunately there are only 7 out of 11 countries instead.

# %% [markdown]
# Of course we want to know how **Indonesia** is developing in 2000 until 2015.

# %%
idn = asean[asean["Country"] == "Indonesia"]
idn
# Out:
#         Country  Year      Status  Life expectancy   Adult Mortality  \
# 1202  Indonesia  2015  Developing              69.1            176.0
# 1203  Indonesia  2014  Developing              68.9            179.0
# 1204  Indonesia  2013  Developing              68.7            181.0
# 1205  Indonesia  2012  Developing              68.5            183.0
# 1206  Indonesia  2011  Developing              68.3            185.0
# 1207  Indonesia  2010  Developing              68.1            187.0
# 1208  Indonesia  2009  Developing              67.9            189.0
# 1209  Indonesia  2008  Developing              67.7            189.0
# 1210  Indonesia  2007  Developing              67.5             19.0
# 1211  Indonesia  2006  Developing              67.3            191.0
# 1212  Indonesia  2005  Developing              67.2             19.0
# 1213  Indonesia  2004  Developing              65.3            213.0
# 1214  Indonesia  2003  Developing              66.9            189.0
# ...

# %%
mas = asean[asean["Country"] == "Malaysia"]

# %% [markdown]
# Ouch, that doesn't look good, let's sort based on **Year** ascending.

# %%
idn.sort_values(by=["Year"])
# Out:
#         Country  Year      Status  Life expectancy   Adult Mortality  \
# 1217  Indonesia  2000  Developing              66.3            188.0
# 1216  Indonesia  2001  Developing              66.5            188.0
# 1215  Indonesia  2002  Developing              66.7            189.0
# 1214  Indonesia  2003  Developing              66.9            189.0
# 1213  Indonesia  2004  Developing              65.3            213.0
# 1212  Indonesia  2005  Developing              67.2             19.0
# 1211  Indonesia  2006  Developing              67.3            191.0
# 1210  Indonesia  2007  Developing              67.5             19.0
# 1209  Indonesia  2008  Developing              67.7            189.0
# 1208  Indonesia  2009  Developing              67.9            189.0
# 1207  Indonesia  2010  Developing              68.1            187.0
# 1206  Indonesia  2011  Developing              68.3            185.0
# 1205  Indonesia  2012  Developing              68.5            183.0
# ...

# %% [markdown]
# Get statistical value for **Indonesia**.

# %%
idn.describe().T
# Out:
#                                  count          mean           std  \
# Year                              16.0  2.007500e+03  4.760952e+00
# Life expectancy                   16.0  6.755625e+01  1.049424e+00
# Adult Mortality                   16.0  1.665625e+02  5.814690e+01
# infant deaths                     16.0  1.511875e+02  2.351515e+01
# Alcohol                           15.0  6.866667e-02  1.355764e-02
# percentage expenditure            16.0  8.376832e+01  8.643873e+01
# Hepatitis B                       16.0  7.356250e+01  8.884209e+00
# Measles                           16.0  1.624494e+04  6.931544e+03
#  BMI                              16.0  1.995625e+01  6.023617e+00
# under-five deaths                 16.0  1.866250e+02  3.418942e+01
# Polio                             16.0  6.218750e+01  3.249455e+01
# Total expenditure                 15.0  2.663333e+00  3.162428e-01
# Diphtheria                        16.0  7.237500e+01  1.795504e+01
# ...

# %% [markdown]
# How growth of Life Expectancy in Indonesia?

# %%
plt.figure(figsize=(20,7)); #(horizontal, vertical)
plt.title("Life Expectancy in Indonesia from 2000-2015")
sns.lineplot(x="Year", y="Life expectancy ", data=idn);

# %%
import plotly.graph_objs as go
# Create a trace
trace = go.Scatter(
    x = idn["Year"],
    y = idn["Life expectancy "]
)
layout = dict(title = 'Life Expectancy in Indonesia from 2000-2015',
              xaxis = dict(title = 'Year'),
              yaxis = dict(title = 'Age'),
              )
data2 = [trace]
fig = dict(data=data2, layout=layout)
iplot(fig, filename='basic-line')
# Out:
# <div id="e66c3dfb-9d44-47df-91ef-90493678b804" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("e66c3dfb-9d44-47df-91ef-90493678b804", [{"x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [69.1, 68.9, 68.7, 68.5, 68.3, 68.1, 67.9, 67.7, 67.5, 67.3, 67.2, 65.3, 66.9, 66.7, 66.5, 66.3], "type": "scatter", "uid": "2906a040-029d-11e9-8e4e-bcee7b0c69ff"}], {"title": "Life Expectancy in Indonesia from 2000-2015", "xaxis": {"title": "Year"}, "yaxis": {"title": "Age"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
import plotly.graph_objs as go
# Create a trace
trace = go.Bar(
    x = idn["Year"],
    y = idn["GDP"],
    text = idn["GDP"],
    textposition = 'auto',
    marker=dict(
        color='rgb(55, 83, 109)'
    )
)
layout = dict(title = 'Gross Domestic Product in Indonesia from 2000-2015',
              xaxis = dict(title = 'Year'),
              yaxis = dict(title = 'GDP'),
              )
data2 = [trace]
fig = dict(data=data2, layout=layout)
iplot(fig, filename='basic-bar')
# Out:
# <div id="2d65464d-ceee-48ba-9bd1-22c05ec5af53" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("2d65464d-ceee-48ba-9bd1-22c05ec5af53", [{"marker": {"color": "rgb(55, 83, 109)"}, "text": [3336.1668600000003, 3491.595887, 362.663981, 3687.953996, 3634.27685, 3113.48635, 2254.4456600000003, 216.52766, 1855.93915, 1586.254, 126.92883400000001, 1148.56996, 164.59447, 899.5556857, 747.9817455, 78.92744], "textposition": "auto", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [3336.1668600000003, 3491.595887, 362.663981, 3687.953996, 3634.27685, 3113.48635, 2254.4456600000003, 216.52766, 1855.93915, 1586.254, 126.92883400000001, 1148.56996, 164.59447, 899.5556857, 747.9817455, 78.92744], "type": "bar", "uid": "2926f95e-029d-11e9-8829-bcee7b0c69ff"
# ...

# %% [markdown]
# Is it good?

# %%
import plotly.graph_objs as go
# Create a trace
trace = go.Bar(
    x = idn["Year"],
    y = idn["infant deaths"],
    text = idn["infant deaths"],
    textposition = 'auto',
    marker=dict(
        color='rgb(55, 83, 109)'
    )
)
layout = dict(title = 'Infant deaths in Indonesia from 2000-2015 (per 1,000 infant)',
              xaxis = dict(title = 'Year'),
              yaxis = dict(title = 'Total infant'),
              )
data2 = [trace]
fig = dict(data=data2, layout=layout)
iplot(fig, filename='basic-bar')
# Out:
# <div id="447873df-0fa3-4c24-9cf0-98013f476bb8" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("447873df-0fa3-4c24-9cf0-98013f476bb8", [{"marker": {"color": "rgb(55, 83, 109)"}, "text": [114.0, 119.0, 124.0, 129.0, 134.0, 138.0, 143.0, 149.0, 154.0, 159.0, 163.0, 174.0, 173.0, 177.0, 182.0, 187.0], "textposition": "auto", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [114, 119, 124, 129, 134, 138, 143, 149, 154, 159, 163, 174, 173, 177, 182, 187], "type": "bar", "uid": "294bbf4c-029d-11e9-b3ac-bcee7b0c69ff"}], {"title": "Infant deaths in Indonesia from 2000-2015 (per 1,000 infant)", "xaxis": {"title": "Year"}, "yaxis": {"title": "Total infant"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
trace1 = go.Bar(
    x = idn["Year"],
    y = idn["infant deaths"],
    text = idn["infant deaths"],
    textposition = 'auto',
    marker=dict(
        color='rgb(55, 83, 109)'
    ),
    name = "Indonesia"
)
trace2 = go.Bar(
    x = mas["Year"],
    y = mas["infant deaths"],
    text = mas["infant deaths"],
    textposition = 'auto',
    name = "Malaysia"
)
layout = dict(title = 'Infant deaths in Indonesia vs Malaysia from 2000-2015 (per 1,000 infant)',
              xaxis = dict(title = 'Year'),
              yaxis = dict(title = 'Total infant'),
              )
data2 = [trace1, trace2]
fig = dict(data=data2, layout=layout)
iplot(fig, filename='basic-bar')
# Out:
# <div id="129ddb56-82ee-430c-b5a9-e39b8210d6a5" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("129ddb56-82ee-430c-b5a9-e39b8210d6a5", [{"marker": {"color": "rgb(55, 83, 109)"}, "name": "Indonesia", "text": [114.0, 119.0, 124.0, 129.0, 134.0, 138.0, 143.0, 149.0, 154.0, 159.0, 163.0, 174.0, 173.0, 177.0, 182.0, 187.0], "textposition": "auto", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [114, 119, 124, 129, 134, 138, 143, 149, 154, 159, 163, 174, 173, 177, 182, 187], "type": "bar", "uid": "297a494c-029d-11e9-9b0b-bcee7b0c69ff"}, {"name": "Malaysia", "text": [4.0, 4.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 4.0, 4.0, 4.0], "textposition": "auto", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004,
# ...

# %%
import plotly.graph_objs as go
# Create a trace
trace1 = go.Scatter(
    x = asean[asean["Country"] == "Indonesia"]["Year"],
    y = asean[asean["Country"] == "Indonesia"]["Life expectancy "],
    name = "Indonesia"
)
trace2 = go.Scatter(
    x = asean[asean["Country"] == "Singapore"]["Year"],
    y = asean[asean["Country"] == "Singapore"]["Life expectancy "],
    name = "Singapore"
)
trace3 = go.Scatter(
    x = asean[asean["Country"] == "Malaysia"]["Year"],
    y = asean[asean["Country"] == "Malaysia"]["Life expectancy "],
    name = "Malaysia"
)
trace4 = go.Scatter(
    x = asean[asean["Country"] == "Thailand"]["Year"],
    y = asean[asean["Country"] == "Thailand"]["Life expectancy "],
    name = "Thailand"
)
trace5 = go.Scatter(
    x = asean[asean["Country"] == "Vietnam"]["Year"],
    y = asean[asean["Country"] == "Vietnam"]["Life expectancy "],
    name = "Vietnam"
)
trace6 = go.Scatter(
    x = asean[asean["Country"] == "Brunei Darussalam"]["Year"],
    y = asean[asean["Country"] == "Brunei Darussalam"]["Life expectancy "],
    name = "Brunei Darussalam"
)
trace7 = go.Scatter(
    x = asean[asean["Country"] == "Phillipines"]["Year"],
    y = asean[asean["Country"] == "Phillipines"]["Life expectancy "],
    name = "Phillipines"
)
trace8 = go.Scatter(
    x = asean[asean["Country"] == "Timor Leste"]["Year"],
    y = asean[asean["Country"] == "Timor Leste"]["Life expectancy "],
    name = "Timor Leste"
)
trace9 = go.Scatter(
    x = asean[asean["Country"] == "Laos"]["Year"],
    y = asean[asean["Country"] == "Laos"]["Life expectancy "],
    name = "Laos"
)
trace10 = go.Scatter(
    x = asean[asean["Country"] == "Cambodia"]["Year"],
    y = asean[asean["Country"] == "Cambodia"]["Life expectancy "],
    name = "Cambodia"
)
trace11 = go.Scatter(
    x = asean[asean["Country"] == "Myanmar"]["Year"],
    y = asean[asean["Country"] == "Myanmar"]["Life expectancy "],
    name = "Myanmar"
)
layout = dict(title = 'Life Expectancy in ASEAN from 2000-2015',
              xaxis = dict(title = 'Year'),
              yaxis = dict(title = 'Age'),
              )
data = [trace1,trace2,trace3,trace4,trace5,trace6,trace7,trace8,trace9,trace10,trace11]
fig = dict(data=data, layout=layout)
iplot(fig, filename='basic-line')
# Out:
# <div id="3068283c-29eb-4109-a39a-e5477d509495" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("3068283c-29eb-4109-a39a-e5477d509495", [{"name": "Indonesia", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [69.1, 68.9, 68.7, 68.5, 68.3, 68.1, 67.9, 67.7, 67.5, 67.3, 67.2, 65.3, 66.9, 66.7, 66.5, 66.3], "type": "scatter", "uid": "29f481e4-029d-11e9-9fc2-bcee7b0c69ff"}, {"name": "Singapore", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000], "y": [83.1, 82.9, 82.7, 82.5, 82.2, 82.0, 81.7, 81.4, 81.1, 87.0, 82.0, 79.7, 79.3, 79.0, 78.7, 78.3], "type": "scatter", "uid": "29f481e5-029d-11e9-b368-bcee7b0c69ff"}, {"name": "Malaysia", "x": [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 200
# ...
